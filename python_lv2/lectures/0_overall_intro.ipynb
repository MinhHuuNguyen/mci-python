# %% [markdown]
# # LESSON 0: OVERALL INTRODUCTION
# <table><tr>
# <td> <img src="../images/conda_logo.png" width="400px"/> </td>
# <td> <img src="../images/jupyter_logo.png" width="400px"/> </td>
# <td> <img src="../images/colab_logo.jpeg" width="400px"/> </td>
# <td> <img src="../images/git_logo.png" width="400px"/> </td>
# </tr></table>

# %% [markdown]
# ## 1. Anaconda and Jupyter notebook introduction
# Anaconda and Jupyter notebook have been introduced. Detail of the introduction can be found [here](https://github.com/MinhHuuNguyen/mci-python/blob/master/python_lv1/lectures/0_conda_and_jupyter_intro.ipynb).

# %% [markdown]
# ## 2. Google Colab introduction
# ### 2.1. Overall introduction
# Google Colab or (Colab for short) is an application developed by Google. <br>
# Colab helps us to run machine learning and especially deep learning models which required lots of computation resources. <br>
# Don't worry about your computer which has no GPU card or low RAM, Colab provide a free resources with Tesla T4 GPU and 12Gb RAM.
#
# ### 2.2. Colab instruction
# #### Create a new `.ipynb` file on Google Drive
# <img src="../images/colab_create.png" width="600px"/>
#
# #### Change Colab language to English
# <img src="../images/colab_change_language.png" width="600px"/>
#
# #### Rename `.ipynb` file
# <img src="../images/colab_rename.png" width="400px"/>
#
# #### Connect Colab to resources
# <img src="../images/colab_connect.png" width="400px"/>
#
# And the result!
#
# <img src="../images/colab_connect_result.png" width="400px"/>
#
# #### Config Colab GPU
# <img src="../images/colab_config_1.png" width="600px"/>
# <img src="../images/colab_config_2.png" width="300px"/>
# <img src="../images/colab_config_3.png" width="300px"/>
#
# #### Write and run code
# Writing and running Python code in Colab is almost similar to using Jupyter notebook.
# <img src="../images/colab_run_code.png" width="600px"/>
#
# #### Connect to Google Drive
# To connect to Google Drive, run the following code <br>
# ``` python
# from google.colab import drive
# drive.mount('/content/gdrive')
# ```
#
# After running the code, a pop-up will appear. Click `Connect to Google Drive`.
#
# <img src="../images/colab_connect_drive_1.png" width="600px"/>
#
# A new browser tab will open. Choose the google account you want to connect.
#
# <img src="../images/colab_connect_drive_2.png" width="300px"/>
#
# Allow Colab to access to your google account.
#
# <img src="../images/colab_connect_drive_3.png" width="300px"/>
#
# If everything is ok, you will get the result.
#
# <img src="../images/colab_connect_drive_4.png" width="400px"/>
#
# #### Check folder tree in Colab
# <img src="../images/colab_folder_tree.png" width="300px"/>
#
# #### Show files in a folder and change folder directory
# Run `!ls` to show all files and folders in a folder. <br>
# Run `%cd <PATH/TO/FOLDER>` to change folder directory.
#
# #### Install Python library in Colab
# Similar to Jupyter notebook `!conda install -c <CHANNEL_NAME> <PACKAGE_NAME>=<VERSION> -y`

# %% [markdown]
# ## 3. Git and Github introduction
# ### 3.1. Git introduction
# Git is a popular version control system and used for:
# - Tracking code changes
# - Tracking who made changes
# - Coding collaboration
#
# Git helps us to:
# - Manage projects with Repositories
# - Clone a project to work on a local copy
# - Control and track changes with Staging and Committing
# - Branch and Merge to allow for work on different parts and versions of a project
# - Pull the latest version of the project to a local copy
# - Push local updates to the main project
#
# #### Git repository and git workflow
# <img src="../images/git_flow.png" width="600px"/>
#
# #### Git branch
# <img src="../images/git_branch_octopus.jpeg" width="500px"/>
#
# <img src="../images/git_branch.png" width="500px"/>
#
# #### Git changes
# <img src="../images/git_changes.png" width="800px"/>
#
# #### Git commit
# <img src="../images/git_changes_flow.png" width="600px"/>
#
# <img src="../images/git_commit_log.png" width="400px"/>
#
# #### Git cheatsheet
# <img src="../images/git_cheat_sheet.webp" width="600px"/>
#
# ### 3.2. Github introduction
# [Github](https://github.com/) is hosting for software development and version control using Git.
#
# #### Github main page
# <img src="../images/github_intro_1.png" width="1000px"/>
#
# #### Create a remote repository
# <img src="../images/github_intro_2.png" width="500px"/>
#
# #### Repository page
# <img src="../images/github_intro_3.png" width="1000px"/>

# %% [markdown]
# ## 4. Data science introduction
# ### 4.1. Workflow for data science
# <img src="../images/data_science_workflow.jpeg" width="800px"/>
#
# ### 4.2. Skils for data science
# <img src="../images/data_science_components.png" width="500px"/>
#
# About Mathematics for Machine learning, we need
# - Linear algebra
# - Probability and statistics
# - Calculus
