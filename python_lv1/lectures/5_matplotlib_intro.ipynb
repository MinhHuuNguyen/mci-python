# %% [markdown]
# # LESSON 5: MATPLOTLIB INTRODUCTION
# <img src="../images/plt_logo.png" width="400px"/>

# %% [markdown]
# ## 1. Overall introduction
# Matplotlib is an open-source Python library for data visualization. <br>
# Matplotlib is the whole package. And it contains 2 modules: `pylab` and `pyplot`. <br>
# - `pyplot` provides the state-machine interface for plotting. That means, each line of code change the state of plotting.
# - `pylab` can be said as the combination of `numpy` functionality and `pyplot` functionality.

# %% [markdown]
# ## 2. Install and import libraries
# Install matplotlib by running this command in jupyter notebook:
# `!conda install -c conda-forge matplotlib -y`

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## 3. Simple plots
# ### 3.1. Line plot
# #### Show single line plot and multiple line plots

# %%
x = np.linspace(-5, 5, 50)

# %%
# single line plot
plt.plot(x, np.sin(x))
plt.show()

# %%
# multiple line plots in multiple lines of code
plt.plot(x, np.sin(x))
plt.plot(x, np.cos(x))
plt.show()

# %%
# multiple lines plot in single line of code
plt.plot(x, np.sin(x), x, np.cos(x))
plt.show()

# %% [markdown]
# #### Change Marker format
# ##### Change marker shape by `marker`
# List of marker shapes [here](https://matplotlib.org/stable/api/markers_api.html)

# %%
plt.plot(x, np.sin(x - 0), marker='p')
plt.plot(x, np.sin(x - 2), marker='v')
plt.plot(x, np.sin(x - 4), marker='<')
plt.show()

# %% [markdown]
# ##### Change marker size by `markersize` or `ms`

# %%
# Using `markersize`
plt.plot(x, np.sin(x - 0), marker='o', markersize=3)
plt.plot(x, np.sin(x - 2), marker='o', markersize=6)
plt.plot(x, np.sin(x - 4), marker='o', markersize=9)
plt.show()

# %%
# Using `ms`
plt.plot(x, np.sin(x - 0), marker='o', ms=3)
plt.plot(x, np.sin(x - 2), marker='o', ms=6)
plt.plot(x, np.sin(x - 4), marker='o', ms=9)
plt.show()

# %% [markdown]
# ##### Change marker edge color by `markeredgecolor` or `mec`

# %%
# Using `markeredgecolor`
plt.plot(x, np.sin(x - 0), marker='o', markeredgecolor='r')
plt.plot(x, np.sin(x - 2), marker='o', markeredgecolor='g')
plt.plot(x, np.sin(x - 4), marker='o', markeredgecolor='b')
plt.show()

# %%
# Using `mec`
plt.plot(x, np.sin(x - 0), marker='o', mec='r')
plt.plot(x, np.sin(x - 2), marker='o', mec='g')
plt.plot(x, np.sin(x - 4), marker='o', mec='b')
plt.show()

# %% [markdown]
# ##### Change marker face color by `markerfacecolor` or `mfc`

# %%
# Using `markerfacecolor`
plt.plot(x, np.sin(x - 0), marker='o', markerfacecolor='r')
plt.plot(x, np.sin(x - 2), marker='o', markerfacecolor='g')
plt.plot(x, np.sin(x - 4), marker='o', markerfacecolor='b')
plt.show()

# %%
# Using `mfc`
plt.plot(x, np.sin(x - 0), marker='o', mfc='r')
plt.plot(x, np.sin(x - 2), marker='o', mfc='g')
plt.plot(x, np.sin(x - 4), marker='o', mfc='b')
plt.show()

# %% [markdown]
# #### Change line color by `color` or `c`
# List of colors [here](https://matplotlib.org/stable/tutorials/colors/colors.html)

# %%
# Using `color`
plt.plot(x, np.sin(x - 0), color='blue')        # Color by name
plt.plot(x, np.sin(x - 1), color='g')           # Color by shortname
plt.plot(x, np.sin(x - 2), color='0.75')        # Grayscale between 0 and 1
plt.plot(x, np.sin(x - 3), color='#FFDD44')     # Hex code (RRGGBB from 00 to FF)
plt.plot(x, np.sin(x - 4), color=(1.0,0.2,0.3)) # RGB tuple, values 0 to 1
plt.show()

# %%
# Using `c`
plt.plot(x, np.sin(x - 0), c='blue')        # Color by name
plt.plot(x, np.sin(x - 1), c='g')           # Color by shortname
plt.plot(x, np.sin(x - 2), c='0.75')        # Grayscale between 0 and 1
plt.plot(x, np.sin(x - 3), c='#FFDD44')     # Hex code (RRGGBB from 00 to FF)
plt.plot(x, np.sin(x - 4), c=(1.0,0.2,0.3)) # RGB tuple, values 0 to 1
plt.show()

# %% [markdown]
# #### Change line style by `linestyle` or `ls`

# %%
# Using `linestyle`
plt.plot(x, x - 1, linestyle='None')
plt.plot(x, x + 0, linestyle='solid')
plt.plot(x, x + 1, linestyle='dashed')
plt.plot(x, x + 2, linestyle='dashdot')
plt.plot(x, x + 3, linestyle='dotted')

plt.plot(x, x - 1, linestyle='')
plt.plot(x, x + 4, linestyle='-')  # solid
plt.plot(x, x + 5, linestyle='--') # dashed
plt.plot(x, x + 6, linestyle='-.') # dashdot
plt.plot(x, x + 7, linestyle=':')  # dotted
plt.show()

# %%
# Using `ls`
plt.plot(x, x - 1, ls='None')
plt.plot(x, x + 0, ls='solid')
plt.plot(x, x + 1, ls='dashed')
plt.plot(x, x + 2, ls='dashdot')
plt.plot(x, x + 3, ls='dotted')

plt.plot(x, x - 1, ls='')   # None
plt.plot(x, x + 4, ls='-')  # solid
plt.plot(x, x + 5, ls='--') # dashed
plt.plot(x, x + 6, ls='-.') # dashdot
plt.plot(x, x + 7, ls=':')  # dotted

# %% [markdown]
# #### Change line width by `linewidth` or `lw`

# %%
# Using `linewidth`
plt.plot(x, x - 1, linewidth='3')
plt.plot(x, x + 2, linewidth='6')
plt.plot(x, x + 5, linewidth='9')
plt.show()

# %%
# Using `lw`
plt.plot(x, x - 1, lw='3')
plt.plot(x, x + 2, lw='6')
plt.plot(x, x + 5, lw='9')
plt.show()

# %% [markdown]
# #### Change line format by Format String
# Format String = `'[marker][line][color]'`

# %%
plt.plot(x, x + 0, '-g')    # [no marker][solid][green]
plt.plot(x, x + 2, 'o--c')  # [circle][dashed][cyan] 
plt.plot(x, x + 4, 's-.k')  # [square][dashdot][black]
plt.show()

# %% [markdown]
# ### 3.2. Scatter plot
# #### Show single scatter plot and multiple scatter plots

# %%
x = np.random.randint(1, 100, size=50)
y = np.random.randint(1, 100, size=50)

# %%
# single scatter plot
plt.scatter(x, y)
plt.show()

# %%
# multiple scatter plots
xx = np.random.randint(1, 100, size=50)
yy = np.random.randint(1, 100, size=50)

plt.scatter(x, y)
plt.scatter(xx, yy)
plt.show()

# %% [markdown]
# #### Change scatter color by `color` or `c`
# List of colors [here](https://matplotlib.org/stable/tutorials/colors/colors.html)

# %%
plt.scatter(x, y, color='r')
plt.scatter(xx, yy, color='b')
plt.show()

# %% [markdown]
# #### Change scatter color map
# List of color map style [here](https://matplotlib.org/stable/tutorials/colors/colormaps.html)

# %%
color_map = np.arange(50)

plt.scatter(x, y, c=color_map, cmap='viridis')
plt.colorbar()
plt.show()

# %% [markdown]
# #### Bubble plot
# Bubble plot is Scatter plot with multiple sizes of scatter

# %%
color_map = np.arange(50)
bubble_size = np.random.randint(1, 200, size=50)

plt.scatter(x, y, s=bubble_size, c=color_map, cmap='viridis')
plt.colorbar()
plt.show()

# %% [markdown]
# ### 3.3. Stack plot

# %%
category = ['category 1', 'category 2', 'category 3', 'category 4', 'category 5']
index = np.arange(5)
value_1 = np.random.randint(10, 50, size=5)
value_2 = np.random.randint(10, 50, size=5)
value_3 = np.random.randint(10, 50, size=5)

# %%
plt.stackplot(category, value_1, value_2, value_3, colors=['r', 'g', 'b'])
plt.show()

# %% [markdown]
# ### 3.4. Bar plot
# #### Show single bar plot

# %%
plt.bar(index, value_1)
plt.show()

# %%
plt.bar(category, value_1)
plt.show()

# %% [markdown]
# #### Show horizontal bar plot

# %%
plt.barh(category, value_1)
plt.show()

# %% [markdown]
# #### Change bar color

# %%
plt.bar(category, value_1, color='r')
plt.show()

# %% [markdown]
# #### Change bar size

# %%
# Change vetical bar width
plt.bar(category, value_1, width=0.5)
plt.show()

# %%
# Change horizontal bar height
plt.barh(category, value_1, height=0.5)
plt.show()

# %% [markdown]
# #### Show multiple bar plots with multiple columns

# %%
# With vertical bar plots
plt.bar(index-0.2, value_1, width=0.2)
plt.bar(index, value_2, width=0.2)
plt.bar(index+0.2, value_3, width=0.2)
plt.show()

# %%
# With horizontal bar plots
plt.barh(index-0.2, value_1, height=0.2)
plt.barh(index, value_2, height=0.2)
plt.barh(index+0.2, value_3, height=0.2)
plt.show()

# %% [markdown]
# #### Show multiple bar plots with stacked columns

# %%
# With horizontal bar plots
plt.bar(index, value_1)
plt.bar(index, value_2, bottom=value_1)
plt.bar(index, value_3, bottom=value_1+value_2)
plt.show()

# %%
# With horizontal bar plots
plt.barh(index, value_1)
plt.barh(index, value_2, left=value_1)
plt.barh(index, value_3, left=value_1+value_2)
plt.show()

# %% [markdown]
# ### 3.5. Pie plot
# #### Show simple pie plot

# %%
category = ['category 1', 'category 2', 'category 3', 'category 4', 'category 5']
value = np.random.randint(10, 100, size=5)

# %%
plt.pie(value)
plt.show()

# %% [markdown]
# #### Add labels

# %%
plt.pie(value, labels=category)
plt.show()

# %% [markdown]
# #### Change start angle
# The default value of `startangle=0`
# <img src="../images/plt_start_angle.png" width="200px"/>

# %%
plt.pie(value, labels=category, startangle=90)
plt.show()

# %% [markdown]
# ### 3.6. Histogram
# A histogram is an approximate representation of the distribution of numerical data. <br>

# %%
y = np.random.normal(-100, 100, 5000)

plt.hist(y)
plt.show()

# %%
yy = np.random.uniform(-100, 100, 5000)

plt.hist(yy)
plt.show()

# %%
# Some additional arguments for histogram
plt.hist(y,                 # data
         bins=50,           # number of bar        
         alpha=0.5,         # opacity
         color='green',     # bar color
         edgecolor='black') # edge of bar color
plt.show()

# %% [markdown]
# ## 4. Plot title, label, legend and text
# ### 4.1. Add title

# %%
x = np.linspace(-5, 5, 50)

# %%
plt.plot(x, np.sin(x))
plt.title("sin(x)")
plt.show()

# %% [markdown]
# ### 4.2. Add label

# %%
plt.plot(x, np.sin(x))
plt.xlabel("x")
plt.ylabel("sin(x)")
plt.show()

# %% [markdown]
# ### 4.3. Add legend

# %%
plt.bar(index-0.2, value_1, width=0.2, label='cat_1')
plt.bar(index, value_2, width=0.2, label='cat_2')
plt.bar(index+0.2, value_3, width=0.2, label='cat_3')
plt.legend()
plt.show()

# %% [markdown]
# ### 4.4. All title, label and legend

# %%
plt.bar(index-0.2, value_1, width=0.2, label='cat_1')
plt.bar(index, value_2, width=0.2, label='cat_2')
plt.bar(index+0.2, value_3, width=0.2, label='cat_3')
plt.legend(loc='upper right')
plt.xlabel("Category")
plt.ylabel("Value")
plt.title("This is my figure")
plt.show()

# %% [markdown]
# ### 4.5. Add text

# %%
plt.hist(y,                 # data
         bins=50,           # number of bar        
         alpha=0.5,         # opacity
         color='green',     # bar color
         edgecolor='black') # edge of bar color
plt.text(-420, 275, 'Normal distribution')
plt.show()

# %% [markdown]
# ### 4.6. Annotate figure

# %%
plt.hist(y,                 # data
         bins=50,           # number of bar        
         alpha=0.5,         # opacity
         color='green',     # bar color
         edgecolor='black') # edge of bar color

plt.annotate('mean',
             xy=(-100, 250), 
             xytext=(100, 270),
             arrowprops=dict(facecolor='black'))
plt.show()

# %% [markdown]
# ## 5. Axes limit in `plt.plot()` or `plt.hist()`
# ### 5.1. Using `plt.xlim()` and `plt.ylim()`
# #### Normal plot

# %%
plt.plot(x, np.sin(x))
plt.show()

# %% [markdown]
# #### With `plt.xlim()` and `plt.ylim()`

# %%
plt.plot(x, np.sin(x))
plt.xlim(-1, 11)
plt.ylim(-1.5, 1.5)
plt.show()

# %% [markdown]
# #### Reverse the axis

# %%
plt.plot(x, np.sin(x))

plt.xlim(-1, 11)
plt.ylim(1.5, -1.5)
plt.show()

# %% [markdown]
# #### With `plt.hist()`

# %%
plt.hist(y,                 # data
         bins=50,           # number of bar        
         alpha=0.5,         # opacity
         color='green',     # bar color
         edgecolor='black') # edge of bar color
plt.show()

# %%
plt.hist(y,                 # data
         bins=50,           # number of bar        
         alpha=0.5,         # opacity
         color='green',     # bar color
         edgecolor='black') # edge of bar color
plt.xlim(-300, 110)
plt.show()

# %% [markdown]
# ### 5.2. Limit axes by `plt.axis()`

# %%
plt.plot(x, np.sin(x))
plt.axis([-1, 11, -1.5, 1.5])
plt.show()

# %% [markdown]
# ### 5.3. Automatically limit axis

# %%
plt.plot(x, np.sin(x))
plt.axis('equal') # ensure aspect ratio
plt.show()

# %% [markdown]
# ## 6. Subplots - Multiple plots
# ### 6.1. Create single sub-plot by `plt.subplot()`

# %%
for subplot_index in range(4):
    plt.subplot(3, 2, subplot_index+1)
    plt.text(0.5, 0.5, f'subplot_index_{subplot_index}', fontsize=12, horizontalalignment='center')
# Add space between subplots
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 6.2. Create the whole sub-plots by `plt.subplots()`

# %%
num_rows, num_cols = 3, 2
fig, ax = plt.subplots(num_rows, num_cols)

for row_index in range(num_rows):
    for col_index in range(num_cols):
        ax[row_index, col_index].text(
            0.5, 0.5, f'subplot_index_{row_index}_{col_index}', fontsize=12, horizontalalignment='center')

# Add space between subplots
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 6.3. More specific subplots by using `plt.GridSpec()`

# %%
grid = plt.GridSpec(3, 3)

plt.subplot(grid[0, 0])
plt.subplot(grid[0, 1:])
plt.subplot(grid[1:, :2])
plt.subplot(grid[1:, 2])
# Add space between subplots
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 6.4. Multiple plots in one figure by `twinx()`

# %%
x = np.linspace(-5, 5, 50)

# %%
fig, ax_1 = plt.subplots()

ax_1.plot(x, np.sin(x), label='sin(x)')
ax_1.set_ylabel('sin(x)')

ax_2 = ax_1.twinx()
ax_2.plot(x, np.exp(x), 'r.-', label='exp(x)')
ax_2.set_ylabel('exp(x)')

fig.legend(loc='upper left')
plt.show()

# %%
x = np.arange(1, 11)
y = np.random.randint(0, 100, 10)
z = np.random.randint(0, 100, 10)

# %%
fig, ax_1 = plt.subplots()

ax_1.bar(x, y, label='y_value')
ax_1.set_ylabel('y_value')

ax_2 = ax_1.twinx()
ax_2.plot(x, z, 'r.-', label='z_value')
ax_2.set_ylabel('z_value')

fig.legend(loc='upper left')
plt.show()

# %% [markdown]
# ## 7. Homework
# Note:
# - We use the daily historical sales data from previous lecture in this homework. (Use this [link](https://drive.google.com/file/d/1R83MNlUShY55i3CzlXpMAMcxnEg4Hruw/view) to download this dataset)
# - All figures must have title, label and legend.
#
# ### 7.1. Exercise 1:
# Randomly choose 3 shops, use `one line plot figure` to show the total turnover of them each month over 33 months (from January 2013 is 0, February 2013 is 1,..., October 2015 is 33.)
# ### 7.2. Exercise 2:
# Randomly choose 1 item, use `one combo figure with bar plot and line plot` to show the sales and the turnover of it over 33 months (from January 2013 is 0, February 2013 is 1,..., October 2015 is 33.)
# ### 7.3. Exercise 3:
# Randomly choose 3 items, use `one bar plot figure` to show the sales of them in 3 years 2013, 2014, and 2015.
# ### 7.4. Exercise 4:
# Randomly choose 1 shop, use `stack plot figure` to show the contribution of turnover of each item each month over 33 months (from January 2013 is 0, February 2013 is 1,..., October 2015 is 33.)
# ### 7.5. Exercise 5:
# Randomly choose 1 shop, use `pie plot figure` to show the contribution of turnover (in percent) of each item in 3 years 2013, 2014, and 2015. (1 pie plot figure for each year, use `subplots` to put all 3 figures together)
# ### 7.6. Exercise 6:
# Randomly choose 1 item, use `histogram figure` to show the distribution of sales of the item over 33 months (from January 2013 is 0, February 2013 is 1,..., October 2015 is 33.)
